# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import os
import csv
path = os.path.join("/content/drive/My Drive/master/Master_git/Master/Code/results/recalculate/")
with open(path + "results_all_with_fails.csv", 'r') as res:
  csv_file = csv.reader(res)
  for row in csv_file:
    print(row)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # New Section
